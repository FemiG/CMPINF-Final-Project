# %% [markdown]
# I will be basing which neighbourhood in Pittsburgh is best on Air Quality.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

Air_Quality = pd.read_csv("Allegheny County Air Quality - Daily.csv", index_col="_id")

# %%
date_query_mask = Air_Quality['date'].str.contains('2024-02-01')
date_sample = Air_Quality[item_query_mask]
date_sample.head(60)
# Out:
#              date                   site parameter  index_value description  \
# _id
# 76330  2024-02-01      Harrison Township       NO2            8        Good
# 76331  2024-02-01           Parkway East       NO2            7        Good
# 76332  2024-02-01             Pittsburgh   NO2_500            9        Good
# 76333  2024-02-01      Harrison Township     OZONE           24        Good
# 76334  2024-02-01         North Braddock  PM25_640           30        Good
# 76335  2024-02-01           Parkway East  PM25_640           29        Good
# 76336  2024-02-01         North Braddock       SO2            3        Good
# 76337  2024-02-01        Lawrenceville 2        CO            2        Good
# 76338  2024-02-01          Lawrenceville     OZONE           22        Good
# 76339  2024-02-01              Liberty 2  PM10_640           11        Good
# 76340  2024-02-01                 Avalon  PM25_640           31        Good
# 76341  2024-02-01              Liberty 2  PM25_640           29        Good
# 76342  2024-02-01         North Braddock        CO            2        Good
# 76343  2024-02-01           Parkway East        CO            4        Good
# 76344  2024-02-01          South Fayette     OZONE           26        Good
# 76345  2024-02-01  Glassport High Street      PM10            9        Good
# 76346  2024-02-01         North Braddock  PM10_640           12        Good
# 76347  2024-02-01                Liberty       SO2            7        Good
# 76348  2024-02-01             Pittsburgh  PM10_640           16        Good
# 76349  2024-02-01        Lawrenceville 2       SO2            1        Good
# 76350  2024-02-01               Clairton  PM25_640           26        Good
# 76351  2024-02-01             Pittsburgh  PM25_640           44        Good
#
#       health_advisory health_effects
# _id
# 76330             NaN            NaN
# 76331             NaN            NaN
# 76332             NaN            NaN
# 76333             NaN            NaN
# 76334             NaN            NaN
# 76335             NaN            NaN
# 76336             NaN            NaN
# 76337             NaN            NaN
# 76338             NaN            NaN
# 76339             NaN            NaN
# 76340             NaN            NaN
# 76341             NaN            NaN
# 76342             NaN            NaN
# 76343             NaN            NaN
# 76344             NaN            NaN
# 76345             NaN            NaN
# 76346             NaN            NaN
# 76347             NaN            NaN
# 76348             NaN            NaN
# 76349             NaN            NaN
# 76350             NaN            NaN
# 76351             NaN            NaN

# %% [markdown]
# With the locations listed above Lawrenceville seems like the best neighbourhood to reside in. Since it has the lowest Sulfur Dioxide presence as well as Carbon Monoxide and Ozone in all the areas recorded. With this information it can be concluded that Lawrenceville has the best air quality in the city and thus the best place to live in the city.
# North Braddock comes in a close second having the 2nd lowest Sulfur Dioxide and Particulate Matter(10 micrometers) in city and tying with Lawrenceville for the lowest Carbon Monoxide levels.
